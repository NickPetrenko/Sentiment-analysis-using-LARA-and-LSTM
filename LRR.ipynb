# %%
import numpy as np
from scipy import optimize
import json
import random
import logging
modelDataDir = "modelData/"

# %%
class LRR:
    def __init__(self):
        self.vocab=[]
        self.vocab = self.loadDataFromFile("vocab.json")
        
        self.aspectKeywords={}
        self.aspectKeywords = self.loadDataFromFile("aspectKeywords.json")
        
        #word to its index in the corpus mapping
        self.wordIndexMapping={} 
        self.createWordIndexMapping()
        
        #aspect to its index in the corpus mapping
        self.aspectIndexMapping={} 
        self.reverseAspIndexmapping={}
        self.createAspectIndexMapping()
        
        #list of Wd matrices of all reviews
        self.wList=[]
        self.wList = self.loadDataFromFile("wList.json")

        #List of ratings dictionaries belonging to review class
        self.ratingsList=[]
        self.ratingsList = self.loadDataFromFile("ratingsList.json")
        
        #List of Review IDs
        self.reviewIdList=[]
        self.reviewIdList = self.loadDataFromFile("reviewIdList.json")
        
        #number of reviews in the corpus
        self.R = len(self.reviewIdList)
        
        #breaking dataset into 3:1 ratio, 3 parts for training and 1 for testing
        self.trainIndex = random.sample(range(0, self.R), int(0.75*self.R))
        self.testIndex = list(set(range(0, self.R)) - set(self.trainIndex))

        #number of aspects
        self.k = len(self.aspectIndexMapping)
        
        #number of training reviews in the corpus
        self.Rn = len(self.trainIndex)
        
        #vocab size
        self.n = len(self.wordIndexMapping)
        
        #delta - is simply a number
        self.delta = 1.0
        
        #matrix of aspect rating vectors (Sd) of all reviews - k*Rn
        self.S = np.empty(shape=(self.k, self.Rn), dtype=np.float64)
        
        #matrix of alphas (Alpha-d) of all reviews - k*Rn
        #each column represents Aplha-d vector for a review
        self.alpha = np.random.dirichlet(np.ones(self.k), size=1).reshape(self.k, 1)
        for i in range(self.Rn-1):
            self.alpha = np.hstack((self.alpha, np.random.dirichlet(np.ones(self.k), size=1).reshape(self.k, 1)))
        
        #vector mu - k*1 vector
        self.mu = np.random.dirichlet(np.ones(self.k), size=1).reshape(self.k, 1)
        
        #matrix Beta for the whole corpus (for all aspects, for all words) - k*n matrix
        self.beta = np.random.uniform(low=-0.1, high=0.1, size=(self.k, self.n))
        
        #matrix sigma for the whole corpus - k*k matrix
        #Sigma needs to be positive definite, with diagonal elems positive
        '''self.sigma = np.random.uniform(low=-1.0, high=1.0, size=(self.k, self.k))
        self.sigma = np.dot(self.sigma, self.sigma.transpose())
        print(self.sigma.shape, self.sigma)
        '''
        
        #Following is help taken from: 
        #https://stats.stackexchange.com/questions/124538/
        W = np.random.randn(self.k, self.k-1)
        S = np.add(np.dot(W, W.transpose()), np.diag(np.random.rand(self.k)))
        D = np.diag(np.reciprocal(np.sqrt(np.diagonal(S))))
        self.sigma = np.dot(D, np.dot(S, D))
        self.sigmaInv=np.linalg.inv(self.sigma)
        
        # testing for positive semi definite
        # if(np.all(np.linalg.eigvals(self.sigma) > 0)): #whether is positive semi definite
        #     print("yes")
        # print(self.sigma)
        
        # setting up logger
        self.logger = logging.getLogger("LRR")
        self.logger.setLevel(logging.INFO)
        self.logger.setLevel(logging.DEBUG)
        fh = logging.FileHandler("lrr.log")
        formatter = logging.Formatter('%(asctime)s %(message)s')
        fh.setFormatter(formatter)
        self.logger.addHandler(fh)
        
    def createWordIndexMapping(self):
        i=0
        for word in self.vocab:
            self.wordIndexMapping[word]=i
            i+=1
        #print(self.wordIndexMapping)
    
    def createAspectIndexMapping(self):
        i=0;
        for aspect in self.aspectKeywords.keys():
            self.aspectIndexMapping[aspect]=i
            self.reverseAspIndexmapping[i]=aspect
            i+=1
        #print(self.aspectIndexMapping)
        
    def loadDataFromFile(self,fileName):
        with open(modelDataDir+fileName,'r') as fp:
            obj=json.load(fp)
            fp.close()
            return obj
    
    #given a dictionary as in every index of self.wList, 
    #creates a W matrix as was in the paper
    def createWMatrix(self, w):
        W = np.zeros(shape=(self.k, self.n))
        for aspect, Dict in w.items():
            for word, freq in Dict.items():
                W[self.aspectIndexMapping[aspect]][self.wordIndexMapping[word]]=freq
        return W
    
    #Computing aspectRating array for each review given Wd->W matrix for review 'd'
    def calcAspectRatings(self,Wd):
        Sd = np.einsum('ij,ij->i',self.beta,Wd).reshape((self.k,))
        try:                                                                                                                     
            Sd = np.exp(Sd)
        except Exception as inst:
            self.logger.info("Exception in calcAspectRatings : %s", Sd)
        return Sd
    
    def calcMu(self): #calculates mu for (t+1)th iteration
        self.mu = np.sum(self.alpha, axis=1).reshape((self.k, 1))/self.Rn
        
    def calcSigma(self, updateDiagonalsOnly): #update diagonal entries only
        self.sigma.fill(0)
        for i in range(self.Rn):
            columnVec = self.alpha[:, i].reshape((self.k, 1))
            columnVec = columnVec - self.mu
            if updateDiagonalsOnly:
                for k in range(self.k):
                    self.sigma[k][k] += columnVec[k]*columnVec[k]
            else:
                self.sigma = self.sigma + np.dot(columnVec, columnVec.transpose())
        for i in range(self.k):
                self.sigma[i][i] = (1.0+self.sigma[i][i])/(1.0+self.Rn)
        self.sigmaInv=np.linalg.inv(self.sigma)
    
    def calcOverallRating(self,alphaD,Sd):
        return np.dot(alphaD.transpose(),Sd)[0][0]
        
    def calcDeltaSquare(self):
        self.delta=0.0
        for i in range(self.Rn):
            alphaD=self.alpha[:,i].reshape((self.k, 1))
            Sd=self.S[:,i].reshape((self.k, 1))
            Rd=float(self.ratingsList[self.trainIndex[i]]["overall"])
            temp=Rd-self.calcOverallRating(alphaD,Sd)
            try:
                self.delta+=(temp*temp)
            except Exception:
                self.logger.info("Exception in Delta calc")
        self.delta/=self.Rn
    
    def maximumLikelihoodBeta(self,x,*args):
        beta = x
        beta=beta.reshape((self.k,self.n))
        innerBracket = np.empty(shape=self.Rn)
        for d in range(self.Rn):
            tmp = 0.0
            rIdx = self.trainIndex[d] #review index in wList
            for i in range(self.k):
                W = self.createWMatrix(self.wList[rIdx])
                tmp += self.alpha[i][d]*np.dot(beta[i, :].reshape((1, self.n)), W[i, :].reshape((self.n, 1)))[0][0]
            innerBracket[d] = tmp - float(self.ratingsList[rIdx]["overall"])
        mlBeta=0.0
        for d in range(self.Rn):
            mlBeta+=innerBracket[d] * innerBracket[d]
        return mlBeta/(2*self.delta)
    
    def gradBeta(self,x,*args):
        beta=x
        beta=beta.reshape((self.k,self.n))
        gradBetaMat=np.empty(shape=((self.k,self.n)),dtype='float64')
        innerBracket = np.empty(shape=self.Rn)
        for d in range(self.Rn):
            tmp = 0.0
            rIdx = self.trainIndex[d] #review index in wList
            for i in range(self.k):
                W = self.createWMatrix(self.wList[rIdx])
                tmp += self.alpha[i][d]*np.dot(beta[i, :].reshape((1, self.n)), W[i, :].reshape((self.n, 1)))[0][0]
            innerBracket[d] = tmp - float(self.ratingsList[rIdx]["overall"])
        
        for i in range(self.k):
            beta_i=np.zeros(shape=(1,self.n))
            for d in range(self.Rn):
                rIdx = self.trainIndex[d] #review index in wList
                W = self.createWMatrix(self.wList[rIdx])
                beta_i += innerBracket[d] * self.alpha[i][d] *  W[i, :]
            gradBetaMat[i,:]=beta_i
        return gradBetaMat.reshape((self.k*self.n, ))
            
    def calcBeta(self):
        beta, retVal, flags=optimize.fmin_l_bfgs_b(func=self.maximumLikelihoodBeta,x0=self.beta,fprime=self.gradBeta,args=(),m=5,maxiter=20000)
        converged = True
        if flags['warnflag']!=0:
            converged = False
        self.logger.info("Beta converged : %d", flags['warnflag'])
        return beta.reshape((self.k,self.n)), converged
                
    def maximumLikelihoodAlpha(self, x, *args):
        alphad=x
        alphad=alphad.reshape((self.k, 1))
        rd,Sd,deltasq,mu,sigmaInv=args
        temp1=(rd-np.dot(alphad.transpose(),Sd)[0][0])
        temp1*=temp1
        temp1/=(deltasq*2)
        temp2=(alphad-mu)
        temp2=np.dot(np.dot(temp2.transpose(),sigmaInv),temp2)[0][0]
        temp2/=2
        return temp1+temp2
    
    def gradAlpha(self, x,*args):
        alphad=x
        alphad=alphad.reshape((self.k, 1))
        rd,Sd,deltasq,mu,sigmaInv=args
        temp1=(np.dot(alphad.transpose(),Sd)[0][0]-rd)*Sd
        temp1/=deltasq
        temp2=np.dot(sigmaInv,(alphad-mu))
        return (temp1+temp2).reshape((self.k,))
    
    def calcAlphaD(self,i):
        alphaD=self.alpha[:,i].reshape((self.k,1))
        rIdx = self.trainIndex[i]
        rd=float(self.ratingsList[rIdx]["overall"])
        Sd=self.S[:,i].reshape((self.k,1))
        Args=(rd,Sd,self.delta,self.mu,self.sigmaInv)
        bounds=[(0,1)]*self.k
        #self.gradf(alphaD, *Args)
        alphaD, retVal, flags=optimize.fmin_l_bfgs_b(func=self.maximumLikelihoodAlpha,x0=alphaD,fprime=self.gradAlpha,args=Args,bounds=bounds,m=5,maxiter=20000)
        converged = True
        if flags['warnflag']!=0:
            converged = False
        self.logger.info("Alpha Converged : %d", flags['warnflag'])
        #Normalizing alphaD so that it follows dirichlet distribution
        alphaD=np.exp(alphaD)
        alphaD=alphaD/(np.sum(alphaD))
        return alphaD.reshape((self.k,)), converged
    
    '''
    def getBetaLikelihood(self):
        likelihood=0
        return self.lambda*np.sum(np.einsum('ij,ij->i',self.beta,self.beta))
    '''
                
    def dataLikelihood(self):
        likelihood=0.0
        for d in range(self.Rn):
            rIdx = self.trainIndex[d]
            Rd=float(self.ratingsList[rIdx]["overall"])
            W=self.createWMatrix(self.wList[rIdx])
            Sd=self.calcAspectRatings(W).reshape((self.k, 1))
            alphaD=self.alpha[:,d].reshape((self.k, 1))
            temp=Rd-self.calcOverallRating(alphaD,Sd)
            try:                                                                                                                 
                likelihood+=(temp*temp)
            except Exception:
                self.logger.debug("Exception in dataLikelihood")
        likelihood/=self.delta
        return likelihood
    
    def alphaLikelihood(self):
        likelihood=0.0
        for d in range(self.Rn):
            alphad=self.alpha[:,d].reshape((self.k, 1))
            temp2=(alphad-self.mu)
            temp2=np.dot(np.dot(temp2.transpose(),self.sigmaInv),temp2)[0]
            likelihood+=temp2
        try:
            likelihood+=np.log(np.linalg.det(self.sigma))
        except FloatingPointError:
            self.logger.debug("Exception in alphaLikelihood: %f", np.linalg.det(self.sigma))
        return likelihood
    
    def calcLikelihood(self):
        likelihood=0.0
        likelihood+=np.log(self.delta) #delta likelihood
        likelihood+=self.dataLikelihood() #data likelihood - will capture beta likelihood too
        likelihood+=self.alphaLikelihood() #alpha likelihood
        return likelihood
    
    def EStep(self):
        for i in range(self.Rn):
            rIdx = self.trainIndex[i]
            W=self.createWMatrix(self.wList[rIdx])
            self.S[:,i]=self.calcAspectRatings(W)
            alphaD, converged = self.calcAlphaD(i)
            if converged:
                self.alpha[:,i]=alphaD
            self.logger.info("Alpha calculated")
            
    def MStep(self):
        likelihood=0.0
        self.calcMu()
        self.logger.info("Mu calculated")
        self.calcSigma(False)
        self.logger.info("Sigma calculated : %s " % np.linalg.det(self.sigma))
        likelihood+=self.alphaLikelihood() #alpha likelihood
        self.logger.info("alphaLikelihood calculated") 
        beta,converged=self.calcBeta()
        if converged:
            self.beta=beta
        self.logger.info("Beta calculated")
        likelihood+=self.dataLikelihood() #data likelihood - will capture beta likelihood too
        self.logger.info("dataLikelihood calculated")
        self.calcDeltaSquare()
        self.logger.info("Deltasq calculated")
        likelihood+=np.log(self.delta) #delta likelihood
        return likelihood
            
    def EMAlgo(self, maxIter, coverge):
        self.logger.info("Training started")
        iteration = 0
        old_likelihood = self.calcLikelihood()
        self.logger.info("initial calcLikelihood calculated, det(Sig): %s" % np.linalg.det(self.sigma)) 
        diff = 10.0
        while(iteration<min(8, maxIter) or (iteration<maxIter and diff>coverge)):
            self.EStep()
            self.logger.info("EStep completed") 
            likelihood = self.MStep()
            self.logger.info("MStep completed")
            diff = (old_likelihood-likelihood)/old_likelihood
            old_likelihood=likelihood
            iteration+=1
        self.logger.info("Training completed")
    
    def testing(self):
        for i in range(self.R-self.Rn):
            rIdx = self.testIndex[i]
            W = self.createWMatrix(self.wList[rIdx])
            Sd = self.calcAspectRatings(W).reshape((self.k,1))
            overallRating = self.calcOverallRating(self.mu,Sd)
            print("ReviewId-",self.reviewIdList[rIdx])
            print("Actual OverallRating:",self.ratingsList[rIdx]["overall"])
            print("Predicted OverallRating:",overallRating)
            print("Actual vs Predicted Aspect Ratings:")
            for aspect, rating in self.ratingsList[rIdx].items():
                aspect_predict = []
                aspect_value = []
                if aspect != "overall" and aspect.lower() in self.aspectIndexMapping.keys():
                    r = self.aspectIndexMapping[aspect.lower()]
                    print("Aspect:",aspect," Rating:",rating, "Predic:", Sd[r])
            if overallRating > 3.0:
                print("Positive Review")
            else:
                print("Negative Review")

# %%
np.seterr(all='raise')
lrrObj = LRR()
lrrObj.EMAlgo(maxIter=1, coverge=0.001)
lrrObj.testing()
# Out:
# ReviewId- 140694805
# Actual OverallRating: 5.0
# Predicted OverallRating: 0.8167596840074209
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.72344067e-18]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Negative Review
# ReviewId- 147758332
# Actual OverallRating: 4.0
# Predicted OverallRating: 6.302695451892643e+22
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [3.43957901e+23]
# Aspect: value  Rating: 4.0 Predic: [1.9385703e+08]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 141485758
# Actual OverallRating: 2.0
# Predicted OverallRating: 1526495.4760554617
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 2.0 Predic: [1.]
# Aspect: cleanliness  Rating: 3.0 Predic: [1.]
# Aspect: value  Rating: 2.0 Predic: [9431553.44543272]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 147625002
# Actual OverallRating: 5.0
# Predicted OverallRating: 1.2735726393458708e+16
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [6.9502862e+16]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 136470026
# Actual OverallRating: 5.0
# Predicted OverallRating: 0.8167783119571871
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [0.00010166]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Negative Review
# ReviewId- 141585490
# Actual OverallRating: 4.0
# Predicted OverallRating: 722654770.6985232
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [3.94375422e+09]
# Aspect: value  Rating: 3.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 141229872
# Actual OverallRating: 5.0
# Predicted OverallRating: 10.933305726732842
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [0.08625026]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 147693766
# Actual OverallRating: 1.0
# Predicted OverallRating: 7216969100434.59
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 2.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [3.93852671e+13]
# Aspect: value  Rating: 1.0 Predic: [1.]
# Aspect: location  Rating: 3.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 2.0 Predic: [1.]
# Positive Review
# ReviewId- 147679428
# Actual OverallRating: 4.0
# Predicted OverallRating: 22764536.544706233
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.23862233e+08]
# Aspect: value  Rating: 4.0 Predic: [420025.97400125]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 147501261
# Actual OverallRating: 4.0
# Predicted OverallRating: 542087890.7445824
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [2.958344e+09]
# Aspect: value  Rating: 3.0 Predic: [0.00028907]
# Aspect: location  Rating: 2.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 147550229
# Actual OverallRating: 4.0
# Predicted OverallRating: 36425033984118.75
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [2.2505461e+14]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 116953463
# Actual OverallRating: 5.0
# Predicted OverallRating: 849.0895236659888
# Actual vs Predicted Aspect Ratings:
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: service  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 147604505
# Actual OverallRating: 5.0
# Predicted OverallRating: 190956170498.78723
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [1.179836e+12]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 127594516
# Actual OverallRating: 4.0
# Predicted OverallRating: 64.26710339966449
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 2450232
# Actual OverallRating: 3.0
# Predicted OverallRating: 166663101.0778725
# Actual vs Predicted Aspect Ratings:
# Positive Review
# ReviewId- 129106359
# Actual OverallRating: 5.0
# Predicted OverallRating: 56002257214.55784
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [3.0562192e+11]
# Aspect: value  Rating: 3.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 143549944
# Actual OverallRating: 5.0
# Predicted OverallRating: 410170744768.8942
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 147074342
# Actual OverallRating: 4.0
# Predicted OverallRating: 189139921194.0131
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.032196e+12]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 143371977
# Actual OverallRating: 3.0
# Predicted OverallRating: 144.3600802793358
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 3.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [886.76024148]
# Aspect: location  Rating: 3.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 3.0 Predic: [1.]
# Positive Review
# ReviewId- 141401617
# Actual OverallRating: 5.0
# Predicted OverallRating: 7739119197.889992
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [0.03695497]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 140996780
# Actual OverallRating: 5.0
# Predicted OverallRating: 737165307.2873178
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [4.02294277e+09]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 146589286
# Actual OverallRating: 5.0
# Predicted OverallRating: 572129452025.7084
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [3.12229025e+12]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 127350105
# Actual OverallRating: 4.0
# Predicted OverallRating: 39059.10912359196
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [213153.37813263]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 142356206
# Actual OverallRating: 5.0
# Predicted OverallRating: 60957874.87708007
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [3.30767843e+08]
# Aspect: value  Rating: 5.0 Predic: [2149339.59820922]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 140325426
# Actual OverallRating: 5.0
# Predicted OverallRating: 3.3643388574188856e+18
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.83602546e+19]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 139498508
# Actual OverallRating: 5.0
# Predicted OverallRating: 0.8400370081588036
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Negative Review
# ReviewId- 135064654
# Actual OverallRating: 5.0
# Predicted OverallRating: 985947806144648.5
# Actual vs Predicted Aspect Ratings:
# Positive Review
# ReviewId- 146346783
# Actual OverallRating: 5.0
# Predicted OverallRating: 109083.96979233505
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [591237.04187701]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 146239820
# Actual OverallRating: 5.0
# Predicted OverallRating: 5.400462583482852e+18
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [2.94720218e+19]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 140650594
# Actual OverallRating: 5.0
# Predicted OverallRating: 110193738.78405857
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1624092.23040339]
# Aspect: value  Rating: 5.0 Predic: [6.79000949e+08]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 138157421
# Actual OverallRating: 5.0
# Predicted OverallRating: 85.29861589908242
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [461.04404349]
# Aspect: value  Rating: 3.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 147200077
# Actual OverallRating: 5.0
# Predicted OverallRating: 5958242472.924209
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [3.25160019e+10]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 147036699
# Actual OverallRating: 4.0
# Predicted OverallRating: 0.8230691400352406
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Negative Review
# ReviewId- 147026010
# Actual OverallRating: 5.0
# Predicted OverallRating: 4.21126129553775e+18
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.64012272e+15]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 146302334
# Actual OverallRating: 5.0
# Predicted OverallRating: 20513094.124031417
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 3.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 7646792
# Actual OverallRating: 3.0
# Predicted OverallRating: 1.2740574019904932e+18
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 3.0 Predic: [1.]
# Aspect: cleanliness  Rating: 3.0 Predic: [6.9529317e+18]
# Aspect: value  Rating: 3.0 Predic: [1.]
# Aspect: location  Rating: 3.0 Predic: [1.]
# Positive Review
# ReviewId- 146166302
# Actual OverallRating: 5.0
# Predicted OverallRating: 68300911929.02883
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [54717493.18998928]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 145774525
# Actual OverallRating: 5.0
# Predicted OverallRating: 0.8334699321671551
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Negative Review
# ReviewId- 134535911
# Actual OverallRating: 4.0
# Predicted OverallRating: 0.8195873146228309
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [0.01543127]
# Aspect: value  Rating: 3.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Negative Review
# ReviewId- 143028515
# Actual OverallRating: 5.0
# Predicted OverallRating: 10.907279031765537
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [62.21281357]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 145753928
# Actual OverallRating: 5.0
# Predicted OverallRating: 8.454859540411433e+35
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [4.6140826e+36]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 144423608
# Actual OverallRating: 5.0
# Predicted OverallRating: 9.573359195054393e+28
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [5.22448302e+29]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 127552737
# Actual OverallRating: 5.0
# Predicted OverallRating: 4.758712827765877
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [21.51247733]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 126013573
# Actual OverallRating: 5.0
# Predicted OverallRating: 36093356832.433815
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [141.65402837]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 142953493
# Actual OverallRating: 5.0
# Predicted OverallRating: 87.51826644268417
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [473.15737418]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 145346806
# Actual OverallRating: 5.0
# Predicted OverallRating: 7.16458754657206e+18
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [3.90994062e+19]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 125810806
# Actual OverallRating: 5.0
# Predicted OverallRating: 2484883.2871694327
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [13560784.68294271]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 144019919
# Actual OverallRating: 5.0
# Predicted OverallRating: 628933.9579569149
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [3885907.0878883]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 143905228
# Actual OverallRating: 5.0
# Predicted OverallRating: 255746037754.2347
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.39568651e+12]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 146699142
# Actual OverallRating: 5.0
# Predicted OverallRating: 16066554728684.47
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [8.76802392e+13]
# Aspect: value  Rating: 5.0 Predic: [5.6139235e-05]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 145041984
# Actual OverallRating: 4.0
# Predicted OverallRating: 1.1656976250448834e+23
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [6.36157834e+23]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 144526561
# Actual OverallRating: 5.0
# Predicted OverallRating: 3545303528.9427004
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.93478357e+10]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 146127461
# Actual OverallRating: 5.0
# Predicted OverallRating: 3654652182.466976
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 146836591
# Actual OverallRating: 5.0
# Predicted OverallRating: 88198.41465633777
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [237.74091488]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 139840762
# Actual OverallRating: 5.0
# Predicted OverallRating: 3729348271.2840834
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [213.43358577]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 139797028
# Actual OverallRating: 4.0
# Predicted OverallRating: 9.4244630135784e+35
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [5.14322569e+36]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 132249260
# Actual OverallRating: 5.0
# Predicted OverallRating: 0.8251652437447824
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Negative Review
# ReviewId- 147094920
# Actual OverallRating: 4.0
# Predicted OverallRating: 12146.258839957953
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 3.0 Predic: [0.0102287]
# Aspect: value  Rating: 4.0 Predic: [75042.44828052]
# Aspect: location  Rating: 3.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 3.0 Predic: [1.]
# Positive Review
# ReviewId- 146960615
# Actual OverallRating: 4.0
# Predicted OverallRating: 16705647.379839985
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [91167964.17092437]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 3.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 145910337
# Actual OverallRating: 5.0
# Predicted OverallRating: 199088.07956543783
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [1086481.76973138]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 146618381
# Actual OverallRating: 4.0
# Predicted OverallRating: 131191.7334094168
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 3.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [810572.0842158]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 130884990
# Actual OverallRating: 4.0
# Predicted OverallRating: 3.204107869878585e+29
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [1.74858238e+30]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 145236667
# Actual OverallRating: 4.0
# Predicted OverallRating: 1.2825921764825853e+18
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [6.99950865e+18]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 146523916
# Actual OverallRating: 5.0
# Predicted OverallRating: 407.87508938826113
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [2221.44525073]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 131537869
# Actual OverallRating: 5.0
# Predicted OverallRating: 85819987.42576727
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [5.30244765e+08]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 126119971
# Actual OverallRating: 4.0
# Predicted OverallRating: 144190320222.26068
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 3.0 Predic: [7.86891899e+11]
# Aspect: value  Rating: 4.0 Predic: [0.52343843]
# Aspect: location  Rating: 2.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 144689864
# Actual OverallRating: 4.0
# Predicted OverallRating: 32.96635600237965
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 3.0 Predic: [198.50635712]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 145863682
# Actual OverallRating: 4.0
# Predicted OverallRating: 2366584651.092434
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 3.0 Predic: [1.46221081e+10]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 145790234
# Actual OverallRating: 4.0
# Predicted OverallRating: 7165431306.029669
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 145758152
# Actual OverallRating: 4.0
# Predicted OverallRating: 14194076419958.049
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 3.0 Predic: [1.]
# Aspect: cleanliness  Rating: 2.0 Predic: [7.74615365e+13]
# Aspect: value  Rating: 3.0 Predic: [0.01017461]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 145627483
# Actual OverallRating: 5.0
# Predicted OverallRating: 57.275902694429654
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 3.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 145595784
# Actual OverallRating: 5.0
# Predicted OverallRating: 35879.383881547335
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [195801.57255686]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 146386668
# Actual OverallRating: 5.0
# Predicted OverallRating: 0.8382020812227773
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [0.00032029]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Negative Review
# ReviewId- 145387387
# Actual OverallRating: 5.0
# Predicted OverallRating: 880110.7281000718
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [5437820.25746698]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 88940860
# Actual OverallRating: 2.0
# Predicted OverallRating: 5893002869.62374
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 1.0 Predic: [1.]
# Aspect: cleanliness  Rating: 3.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 3.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 133288742
# Actual OverallRating: 5.0
# Predicted OverallRating: 5.947120088646402e+23
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [3.24553036e+24]
# Aspect: value  Rating: 4.0 Predic: [0.658069]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 125291863
# Actual OverallRating: 5.0
# Predicted OverallRating: 925273064005.0016
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 144453893
# Actual OverallRating: 4.0
# Predicted OverallRating: 1.6481651011841378
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Negative Review
# ReviewId- 144366760
# Actual OverallRating: 5.0
# Predicted OverallRating: 12365987029.310627
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 146342214
# Actual OverallRating: 5.0
# Predicted OverallRating: 3718528201.406308
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [2.02931772e+10]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 59555834
# Actual OverallRating: 4.0
# Predicted OverallRating: 6762847259.927266
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [3.69069832e+10]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 137048699
# Actual OverallRating: 5.0
# Predicted OverallRating: 287233805.4783002
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 144260325
# Actual OverallRating: 1.0
# Predicted OverallRating: 0.8167596840074209
# Actual vs Predicted Aspect Ratings:
# Aspect: cleanliness  Rating: 1.0 Predic: [5.65169776e-29]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Negative Review
# ReviewId- 133912222
# Actual OverallRating: 4.0
# Predicted OverallRating: 240737560244.04132
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [1.48741378e+12]
# Aspect: location  Rating: 3.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 145460414
# Actual OverallRating: 5.0
# Predicted OverallRating: 0.9645777814588207
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [0.80668982]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Negative Review
# ReviewId- 133310612
# Actual OverallRating: 4.0
# Predicted OverallRating: 22237084.875407133
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 3.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [42046037.0802393]
# Aspect: location  Rating: 3.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 132807180
# Actual OverallRating: 3.0
# Predicted OverallRating: 2.603031378960445e+22
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [1.42055604e+23]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 145283762
# Actual OverallRating: 4.0
# Predicted OverallRating: 2832548.4666210744
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [15458102.84444229]
# Aspect: value  Rating: 3.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 126747106
# Actual OverallRating: 5.0
# Predicted OverallRating: 1.2277869674616533e+29
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [6.7004194e+29]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 143073243
# Actual OverallRating: 5.0
# Predicted OverallRating: 1.2121757335050256e+16
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [6.61522399e+16]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 145753537
# Actual OverallRating: 1.0
# Predicted OverallRating: 4488109.323606941
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 2.0 Predic: [1.]
# Aspect: cleanliness  Rating: 2.0 Predic: [24493018.81267777]
# Aspect: value  Rating: 2.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 145229211
# Actual OverallRating: 5.0
# Predicted OverallRating: 13886830550.242231
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [7.57847992e+10]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 144415850
# Actual OverallRating: 5.0
# Predicted OverallRating: 21181459164105.023
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [1.30871121e+14]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 145712846
# Actual OverallRating: 5.0
# Predicted OverallRating: 708235830.6424545
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [3.86506553e+09]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 142382827
# Actual OverallRating: 5.0
# Predicted OverallRating: 1.3194598797196843e+28
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [7.20070729e+28]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 138579808
# Actual OverallRating: 5.0
# Predicted OverallRating: 67.66198473067678
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [0.00317205]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 120022931
# Actual OverallRating: 4.0
# Predicted OverallRating: 918507.433713755
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [4996199.46540588]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 145131219
# Actual OverallRating: 5.0
# Predicted OverallRating: 3288658639228.3164
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.79472439e+13]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 130745334
# Actual OverallRating: 3.0
# Predicted OverallRating: 12221810850553.02
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [6.66982633e+13]
# Aspect: value  Rating: 3.0 Predic: [1.]
# Aspect: location  Rating: 3.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 1.0 Predic: [1.]
# Positive Review
# ReviewId- 7365010
# Actual OverallRating: 4.0
# Predicted OverallRating: 65955904022.816055
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [3.59942099e+11]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 126295249
# Actual OverallRating: 5.0
# Predicted OverallRating: 1007408484718.727
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [5.49774475e+12]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 143830305
# Actual OverallRating: 3.0
# Predicted OverallRating: 6700159.749507832
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 1.0 Predic: [1.]
# Aspect: cleanliness  Rating: 3.0 Predic: [1.]
# Aspect: value  Rating: 1.0 Predic: [1842.01474809]
# Aspect: location  Rating: 3.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 142279206
# Actual OverallRating: 4.0
# Predicted OverallRating: 2.426743901731312
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [9.81523657]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Negative Review
# ReviewId- 115174547
# Actual OverallRating: 5.0
# Predicted OverallRating: 308.28901996069567
# Actual vs Predicted Aspect Ratings:
# Aspect: cleanliness  Rating: 5.0 Predic: [1677.97276823]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: service  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 129832461
# Actual OverallRating: 5.0
# Predicted OverallRating: 1605.8937966690705
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [8759.40989455]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 143426886
# Actual OverallRating: 4.0
# Predicted OverallRating: 59088315.58028571
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [0.15592024]
# Aspect: value  Rating: 4.0 Predic: [3.6508127e+08]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 126713675
# Actual OverallRating: 5.0
# Predicted OverallRating: 0.8167596840074303
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [5.05298775e-14]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Negative Review
# ReviewId- 102853553
# Actual OverallRating: 5.0
# Predicted OverallRating: 31612816317.522343
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.72521075e+11]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 143954290
# Actual OverallRating: 5.0
# Predicted OverallRating: 9.565853365021914e+21
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [5.22038685e+22]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 144984659
# Actual OverallRating: 4.0
# Predicted OverallRating: 2018956982.5073175
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [1.24742548e+10]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 141014046
# Actual OverallRating: 5.0
# Predicted OverallRating: 1.2124981708923459e+44
# Actual vs Predicted Aspect Ratings:
# Positive Review
# ReviewId- 145473502
# Actual OverallRating: 5.0
# Predicted OverallRating: 74.14778834582927
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 135962412
# Actual OverallRating: 5.0
# Predicted OverallRating: 835.0439319984972
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [5154.19852763]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 64406398
# Actual OverallRating: 3.0
# Predicted OverallRating: 18641279.830325406
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 3.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [1.]
# Aspect: value  Rating: 3.0 Predic: [1.]
# Aspect: location  Rating: 3.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 3.0 Predic: [1.]
# Positive Review
# ReviewId- 64089816
# Actual OverallRating: 2.0
# Predicted OverallRating: 0.828022022551099
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 2.0 Predic: [1.]
# Aspect: cleanliness  Rating: 3.0 Predic: [1.]
# Aspect: value  Rating: 2.0 Predic: [1.]
# Aspect: location  Rating: 1.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 3.0 Predic: [1.]
# Negative Review
# ReviewId- 143940108
# Actual OverallRating: 5.0
# Predicted OverallRating: 31612816317.522343
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.72521075e+11]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 144827474
# Actual OverallRating: 5.0
# Predicted OverallRating: 222532.1917509575
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1214423.65882127]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 142699336
# Actual OverallRating: 4.0
# Predicted OverallRating: 2862310192.125147
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 3.0 Predic: [1.76849829e+10]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 138473405
# Actual OverallRating: 3.0
# Predicted OverallRating: 1.7617878287717774e+22
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 2.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 3.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 34835731
# Actual OverallRating: 3.0
# Predicted OverallRating: 23157359.1241866
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 2.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [1.26376983e+08]
# Aspect: value  Rating: 3.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 22487350
# Actual OverallRating: 3.0
# Predicted OverallRating: 291789.78323633375
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 3.0 Predic: [1592384.10442638]
# Aspect: value  Rating: 3.0 Predic: [1.]
# Aspect: location  Rating: 3.0 Predic: [1.]
# Positive Review
# ReviewId- 143653948
# Actual OverallRating: 4.0
# Predicted OverallRating: 6883229376616.207
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 3.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [3.75639462e+13]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 138830116
# Actual OverallRating: 5.0
# Predicted OverallRating: 103182362366.08276
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [2.77263502e-05]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 144633364
# Actual OverallRating: 5.0
# Predicted OverallRating: 13.198680302638419
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 3.0 Predic: [1.]
# Positive Review
# ReviewId- 144953481
# Actual OverallRating: 5.0
# Predicted OverallRating: 4.007624017148288e+37
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [3.40474771e+18]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 135300639
# Actual OverallRating: 5.0
# Predicted OverallRating: 120474.22810012866
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [657461.27258001]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 133778187
# Actual OverallRating: 5.0
# Predicted OverallRating: 8436192592236.1875
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [4.60389546e+13]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 143956716
# Actual OverallRating: 5.0
# Predicted OverallRating: 2390849307676.736
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.30476162e+13]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 143302210
# Actual OverallRating: 5.0
# Predicted OverallRating: 472.6963167862335
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [2915.40854839]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 94047849
# Actual OverallRating: 5.0
# Predicted OverallRating: 0.8167625616013766
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.57039347e-05]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Negative Review
# ReviewId- 142419833
# Actual OverallRating: 5.0
# Predicted OverallRating: 193312604.47635928
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.05496764e+09]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 122678797
# Actual OverallRating: 5.0
# Predicted OverallRating: 1.8214644887301956e+16
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [9.94030423e+16]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 132193295
# Actual OverallRating: 5.0
# Predicted OverallRating: 265090299600766.1
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.44665186e+15]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 139528680
# Actual OverallRating: 5.0
# Predicted OverallRating: 8819.78882389231
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [54488.5010047]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 142106336
# Actual OverallRating: 5.0
# Predicted OverallRating: 6201821887.229855
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [3.38452914e+10]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 119864481
# Actual OverallRating: 5.0
# Predicted OverallRating: 0.8202218208022553
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [0.01889397]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Negative Review
# ReviewId- 142012721
# Actual OverallRating: 5.0
# Predicted OverallRating: 429780629749243.44
# Actual vs Predicted Aspect Ratings:
# Positive Review
# ReviewId- 142910902
# Actual OverallRating: 5.0
# Predicted OverallRating: 150461023586.45975
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [8.21113098e+11]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 117727458
# Actual OverallRating: 5.0
# Predicted OverallRating: 201145492.32093835
# Actual vs Predicted Aspect Ratings:
# Aspect: cleanliness  Rating: 5.0 Predic: [6.41938279]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [1602.12181025]
# Aspect: service  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 132469139
# Actual OverallRating: 5.0
# Predicted OverallRating: 0.8954407092957053
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 4.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Negative Review
# ReviewId- 144426236
# Actual OverallRating: 5.0
# Predicted OverallRating: 107601.67065228288
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [587211.68051771]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 144250740
# Actual OverallRating: 3.0
# Predicted OverallRating: 3966479918552494.0
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 2.0 Predic: [1.]
# Aspect: cleanliness  Rating: 3.0 Predic: [0.06719734]
# Aspect: value  Rating: 2.0 Predic: [2.45071725e+16]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 142162149
# Actual OverallRating: 5.0
# Predicted OverallRating: 17.504495065560043
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 5.0 Predic: [102.97417235]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 141372583
# Actual OverallRating: 4.0
# Predicted OverallRating: 2175106997754.3054
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [7.92609428e+10]
# Aspect: value  Rating: 5.0 Predic: [1.33493138e+13]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 141293665
# Actual OverallRating: 4.0
# Predicted OverallRating: 35995618122.05695
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.96439402e+11]
# Aspect: value  Rating: 3.0 Predic: [1.]
# Aspect: location  Rating: 4.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 4.0 Predic: [1.]
# Positive Review
# ReviewId- 139207395
# Actual OverallRating: 3.0
# Predicted OverallRating: 149597715327.6555
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 2.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 2.0 Predic: [9.24299904e+11]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 138885668
# Actual OverallRating: 5.0
# Predicted OverallRating: 41.53293613880316
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [1.]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 138687015
# Actual OverallRating: 5.0
# Predicted OverallRating: 380546969.8128269
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [2.07676442e+09]
# Aspect: value  Rating: 4.0 Predic: [1.]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 5009973
# Actual OverallRating: 5.0
# Predicted OverallRating: 596877.1632026421
# Actual vs Predicted Aspect Ratings:
# Aspect: cleanliness  Rating: 4.0 Predic: [3257341.83118922]
# Aspect: value  Rating: 5.0 Predic: [1.]
# Aspect: service  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 3449313
# Actual OverallRating: 5.0
# Predicted OverallRating: 1.0718685589985944e+23
# Actual vs Predicted Aspect Ratings:
# Positive Review
# ReviewId- 130135518
# Actual OverallRating: 5.0
# Predicted OverallRating: 301374049766774.5
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 5.0 Predic: [625710.86473444]
# Aspect: value  Rating: 5.0 Predic: [1.86206056e+15]
# Aspect: location  Rating: 5.0 Predic: [1.]
# Aspect: sleep_quality  Rating: 5.0 Predic: [1.]
# Positive Review
# ReviewId- 29440811
# Actual OverallRating: 4.0
# Predicted OverallRating: 31589.047268009923
# Actual vs Predicted Aspect Ratings:
# Aspect: service  Rating: 5.0 Predic: [1.]
# Aspect: cleanliness  Rating: 4.0 Predic: [1.]
# Aspect: value  Rating: 3.0 Predic: [195169.95025188]
# Aspect: location  Rating: 2.0 Predic: [1.]
# Positive Review
